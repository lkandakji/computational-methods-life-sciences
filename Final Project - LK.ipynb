# %% [markdown]
# # Final Project

# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %% [markdown]
# # Africa

# %%
df = pd.read_csv('Combined_data_Africa.csv', usecols=[1,3,4])
print('AFRICA CORRELATION DATAFRAME: ')
print('')
df.corr()
# Out:
# AFRICA CORRELATION DATAFRAME:
#                  BMI       GDP  Population
# BMI         1.000000  0.567002    0.053455
# GDP         0.567002  1.000000   -0.125457
# Population  0.053455 -0.125457    1.000000

# %%
corr = df.corr()
plt.figure(figsize = (10,6))
sb.heatmap(corr, fmt="g", cmap='RdBu')
plt.title('CORRELATION HEATMAP')
plt.show()

# %% [markdown]
# ## GDP vs BMI

# %%
df = pd.read_csv('Combined_data_Africa.csv')
Continents_Africa = df
Continents_Africa.plot.scatter('BMI','GDP')
plt.show()

# %% [markdown]
# # Asia

# %%
df = pd.read_csv('Combined_data_Asia.csv', usecols=[1,3,4])
print('ASIA CORRELATION DATAFRAME: ')
print('')
df.corr()
# Out:
# ASIA CORRELATION DATAFRAME:
#                  BMI       GDP  Population
# BMI         1.000000  0.527719   -0.254732
# GDP         0.527719  1.000000   -0.150284
# Population -0.254732 -0.150284    1.000000

# %%
corr = df.corr()
plt.figure(figsize = (10,6))
sb.heatmap(corr, fmt="g", cmap='RdBu')
plt.title('CORRELATION HEATMAP')
plt.show()

# %% [markdown]
# ## GDP vs BMI

# %%
df = pd.read_csv('Combined_Data_Asia.csv')
Continents_Asia = df
Continents_Asia.plot.scatter('BMI','GDP')
plt.show()

# %% [markdown]
# # Europe

# %%
df = pd.read_csv('Combined_data_Europe.csv', usecols=[1,3,4])
print('EUROPE CORRELATION DATAFRAME: ')
print('')
df.corr()
# Out:
# EUROPE CORRELATION DATAFRAME:
#                  BMI       GDP  Population
# BMI         1.000000  0.492603   -0.093783
# GDP         0.492603  1.000000   -0.023797
# Population -0.093783 -0.023797    1.000000

# %%
corr = df.corr()
plt.figure(figsize = (10,6))
sb.heatmap(corr, fmt="g", cmap='RdBu')
plt.title('CORRELATION HEATMAP')
plt.show()

# %% [markdown]
# ## GDP vs BMI

# %%
df = pd.read_csv('Combined_Data_Europe.csv')
Continents_Europe = df
Continents_Europe.plot.scatter('BMI','GDP')
plt.show()

# %% [markdown]
# # South America

# %%
df = pd.read_csv('Combined_data_SA.csv', usecols=[1,3,4])
print('SOUTH AMERICA CORRELATION DATAFRAME: ')
print('')
df.corr()
# Out:
# SOUTH AMERICA CORRELATION DATAFRAME:
#                  BMI       GDP  Population
# BMI         1.000000  0.904503    0.256883
# GDP         0.904503  1.000000    0.305491
# Population  0.256883  0.305491    1.000000

# %%
corr = df.corr()
plt.figure(figsize = (10,6))
sb.heatmap(corr, fmt="g", cmap='RdBu')
plt.title('CORRELATION HEATMAP')
plt.show()

# %% [markdown]
# ## GDP vs BMI

# %%
df = pd.read_csv('Combined_data_SA.csv')
Continents_SA = df
Continents_SA.plot.scatter('BMI','GDP')
plt.show()

# %% [markdown]
# # North America

# %%
df = pd.read_csv('Combined_data_NA.csv', usecols=[1,3,4])
print('NORTH AMERICA CORRELATION DATAFRAME: ')
print('')
df.corr()
# Out:
# NORTH AMERICA CORRELATION DATAFRAME:
#                 BMI       GDP  Population
# BMI         1.00000  0.490860    0.219660
# GDP         0.49086  1.000000    0.317128
# Population  0.21966  0.317128    1.000000

# %%
corr = df.corr()
plt.figure(figsize = (10,6))
sb.heatmap(corr, fmt="g", cmap='RdBu')
plt.title('CORRELATION HEATMAP')
plt.show()

# %% [markdown]
# ## GDP vs BMI

# %%
df = pd.read_csv('Combined_data_NA.csv')
Continents_NA = df
Continents_NA.plot.scatter('BMI','GDP')
plt.show()

# %% [markdown]
# # Oceania

# %%
df = pd.read_csv('Combined_data_Oceania.csv', usecols=[1,3,4])
print('OCEANIA CORRELATION DATAFRAME: ')
print('')
df.corr()
# Out:
# OCEANIA CORRELATION DATAFRAME:
#                  BMI       GDP  Population
# BMI         1.000000 -0.066211   -0.323586
# GDP        -0.066211  1.000000    0.783093
# Population -0.323586  0.783093    1.000000

# %%
corr = df.corr()
plt.figure(figsize = (10,6))
sb.heatmap(corr, fmt="g", cmap='RdBu')
plt.title('CORRELATION HEATMAP')
plt.show()

# %% [markdown]
# ## GDP vs BMI

# %%
df = pd.read_csv('Combined_Data_Oceania.csv')
Continents_Oceania = df
Continents_Oceania.plot.scatter('BMI','GDP')
plt.show()

# %% [markdown]
# # Global

# %%
df = pd.read_csv('Combined-Data.csv', usecols=[1,3,4])
print('GLOBAL CORRELATION DATAFRAME: ')
print('')
df.corr()
# Out:
# GLOBAL CORRELATION DATAFRAME:
#                        BMI       GDP  Total Population
# BMI               1.000000  0.506125         -0.154417
# GDP               0.506125  1.000000         -0.060307
# Total Population -0.154417 -0.060307          1.000000

# %%
corr = df.corr()
plt.figure(figsize = (10,6))
sb.heatmap(corr, fmt="g", cmap='RdBu')
plt.title('CORRELATION HEATMAP')
plt.show()

# %% [markdown]
# ## GDP vs BMI

# %%
df = pd.read_csv('Combined-Data.csv')
All_Continents = df
All_Continents.plot.scatter('BMI' , 'GDP')
plt.show()

# %% [markdown]
# # GDP vs BMI vs Population Size Globally

# %%
def read_data(filename, data_type=float):

    data = {}
    with open(filename, 'r') as fi:
        for line in fi.readlines():
            fields = line.split('\t')
            if len(fields) != 2:
                continue
            country, value = fields[0], fields[1].strip()
            if not value:
                continue
            data[country] = data_type(value)
    return data

raw_pop = read_data('population_total.tsv')
raw_bmi = read_data('bmi_men.tsv')
raw_gdp = read_data('gdp.tsv')
continent = read_data('continents.tsv', str)

countries = set(raw_pop.keys()) & set(raw_bmi.keys()) & set(raw_gdp.keys())\
            & set(continent.keys())
countries = sorted(list(countries))

pop = np.array([raw_pop[country] for country in countries])
bmi = np.array([raw_bmi[country] for country in countries])
gdp = np.array([raw_gdp[country] for country in countries])

continent_colours = {'Africa': 'b', 'Asia': 'r', 'North America': 'y',
                     'South America': 'm', 'Europe': 'g', 'Oceania': 'c'}
colours = [continent_colours[continent[country]] for country in countries]
sizes = np.clip(pop / 1.e9 * 2000, 16, None)
fig = plt.figure()
ax = fig.add_subplot(111)
fig.set_figheight(7)
fig.set_figwidth(10)
sct = ax.scatter(gdp, bmi, s=sizes, c=colours, edgecolor='w')
sct.set_alpha(0.75)
ax.set_xscale('log')
ax.set_xlabel('GDP per capita')
ax.set_ylabel('Body Mass Index of men (kg/m2)')
plt.show()

# %% [markdown]
# # Bonus: BMI Calculator

# %%
def bmi(inches,pounds):

    weight=pounds/2.20462262
    height=inches * 0.0254
    
    return weight/pow(height,2)


def category(index):

    cat_list=['Underweight','Normal','Overweight','Obese']

    if index < 18.5:

        return cat_list[0]

    elif index >= 18.5 and index < 25:

         return cat_list[1]

    elif index >= 25 and index <30:

        return cat_list[2]

    elif index >=30:
        return cat_list[3]

    else:
        pass

def main():
    height = float( input("enter height in inches: ") )
    weight = float( input("enter weight in pounds: ") )
    bodyMassIndex = bmi(height, weight)
    bmiCat = category(bodyMassIndex)
    allCats = ['Underweight','Normal','Overweight','Obese']
    if bmiCat in allCats:
        print("BMI is {0:.1f}: {1}".format(bodyMassIndex, bmiCat))
    else: print ("Category error:",bmiCat,'\n must be one of ',allCats)

main()
