# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Wright-Fisher Binomial Sampling
#
# In the Wright-Fisher Model, assuming no mutation, migration or selection, the number of alleles in generation `t+1`, given the number of alleles in generation `t`, follows a binomial distribution, i.e,
#
# <img src="eq1.png" width="400">
#
# in which `N` is the population size, and
#
# <img src="eq2.png" width="200">
#
# Hence, the random variable `X_{t+1}` follows a binomial distribution. This can be implemented using `np.random.binomial`.

# %% [markdown]
# # P1
#
# 1. Using binomial random function in python, write a function that given an initial frequency of allele `A` and a given population size `N`, simulates the population history (i.e., an array of counts of allele `A` over different genereations) for a given number of generations.
#
#     For example a possible output of your function `WF_model(N,f,t)`, in which `N` and `t` are integers and `f` is a float, for `N=100,f=0.1,t=10` could be the array `[10,5,4,8,11,15,19,20,22,27]`
#
# 2. Modify your function so that if allele `A` goes to fixation before reaching the specified number of generations `t`, i.e, fA=0 or fA=1, the iteration stops and only returns the history up to the point when the allele got fixed
#
# 3. Plot results of 10 different runs of this simulation

# %%
import numpy as np

print('#1. ')

N = 100.0
f = 0.1
t = 10

s = np.random.binomial(N, f, t)
history = []

for _ in s:
    history.append(_)
        
thehistory = np.array(history)
print('The population history: ' + str(history))

print('')
print('#2. ')
N = 100.0
f = 0.1
t = 10

s = np.random.binomial(N, f, t)
z = s/N
freq = []
for _ in z:
    if _ != 0 or 1:
        freq.append(_)
    else:
        break

y1 = np.array(freq)

print('Round 1 allelic frequency: ' + str(y1))

s = np.random.binomial(N, f, t)
z = s/N
freq = []
for _ in z:
    if _ != 0 or 1:
        freq.append(_)
    else:
        break

y2 = np.array(freq)

print('Round 2 allelic frequency: ' + str(y2))

s = np.random.binomial(N, f, t)
z = s/N
freq = []
for _ in z:
    if _ != 0 or 1:
        freq.append(_)
    else:
        break

y3 = np.array(freq)

print('Round 3 allelic frequency: ' + str(y3))

s = np.random.binomial(N, f, t)
z = s/N
freq = []
for _ in z:
    if _ != 0 or 1:
        freq.append(_)
    else:
        break

y4 = np.array(freq)

print('Round 4 allelic frequency: ' + str(y4))

s = np.random.binomial(N, f, t)
z = s/N
freq = []
for _ in z:
    if _ != 0 or 1:
        freq.append(_)
    else:
        break

y5 = np.array(freq)

print('Round 5 allelic frequency: ' + str(y5))

s = np.random.binomial(N, f, t)
z = s/N
freq = []
for _ in z:
    if _ != 0 or 1:
        freq.append(_)
    else:
        break

y6 = np.array(freq)

print('Round 6 allelic frequency: ' + str(y6))

s = np.random.binomial(N, f, t)
z = s/N
freq = []
for _ in z:
    if _ != 0 or 1:
        freq.append(_)
    else:
        break

y7 = np.array(freq)

print('Round 7 allelic frequency: ' + str(y7))

s = np.random.binomial(N, f, t)
z = s/N
freq = []
for _ in z:
    if _ != 0 or 1:
        freq.append(_)
    else:
        break

y8 = np.array(freq)

print('Round 8 allelic frequency: ' + str(y8))

s = np.random.binomial(N, f, t)
z = s/N
freq = []
for _ in z:
    if _ != 0 or 1:
        freq.append(_)
    else:
        break

y9 = np.array(freq)

print('Round 9 allelic frequency: ' + str(y9))

s = np.random.binomial(N, f, t)
z = s/N
freq = []
for _ in z:
    if _ != 0 or 1:
        freq.append(_)
    else:
        break

y10 = np.array(freq)

print('Round 10 allelic frequency: ' + str(y10))

import matplotlib.pyplot as plt

g=range(10)

print('')
print('#3.')
plt.figure(figsize=(10,7))
plt.plot(g,y1,'r-')
plt.plot(g,y2,'b-')
plt.plot(g,y3,'g-')
plt.plot(g,y4,'y-')
plt.plot(g,y5,'k-')
plt.plot(g,y6,'m-')
plt.plot(g,y7,'C4-')
plt.plot(g,y8,'C9-')
plt.plot(g,y9,'C7-')
plt.plot(g,y10,'C6-')
plt.xlabel('Generation')
plt.ylabel('Allele Frequency')
plt.title('Wright-Fisher Binomial Sampling')
plt.ylim((0, 1))
plt.xlim((0, 9))
plt.grid()
plt.show()

print('Graph Zoomed In:')
plt.figure(figsize=(10,7))
plt.plot(g,y1,'r-')
plt.plot(g,y2,'b-')
plt.plot(g,y3,'g-')
plt.plot(g,y4,'y-')
plt.plot(g,y5,'k-')
plt.plot(g,y6,'m-')
plt.plot(g,y7,'C4-')
plt.plot(g,y8,'C9-')
plt.plot(g,y9,'C7-')
plt.plot(g,y10,'C6-')
plt.xlabel('Generation')
plt.ylabel('Allele Frequency')
plt.title('Wright-Fisher Binomial Sampling')
plt.xlim((0, 9))
plt.grid()
plt.show()
# Out:
# #1.
# The population history: [12, 9, 11, 6, 14, 8, 10, 7, 12, 10]
#
# #2.
# Round 1 allelic frequency: [0.15 0.1  0.1  0.08 0.13 0.1  0.12 0.08 0.13 0.13]
# Round 2 allelic frequency: [0.12 0.13 0.09 0.06 0.12 0.09 0.05 0.08 0.12 0.11]
# Round 3 allelic frequency: [0.09 0.06 0.07 0.08 0.12 0.07 0.08 0.15 0.18 0.18]
# Round 4 allelic frequency: [0.14 0.09 0.12 0.15 0.1  0.13 0.09 0.1  0.06 0.07]
# Round 5 allelic frequency: [0.12 0.07 0.07 0.09 0.1  0.1  0.11 0.06 0.1  0.11]
# Round 6 allelic frequency: [0.1  0.07 0.05 0.17 0.1  0.08 0.11 0.16 0.12 0.13]
# Round 7 allelic frequency: [0.06 0.11 0.1  0.09 0.1  0.08 0.18 0.1  0.08 0.11]
# Round 8 allelic frequency: [0.1  0.07 0.13 0.08 0.14 0.04 0.11 0.06 0.13 0.05]
# Round 9 allelic frequency: [0.11 0.12 0.09 0.12 0.12 0.06 0.09 0.09 0.1  0.11]
# Round 10 allelic frequency: [0.11 0.1  0.04 0.1  0.12 0.09 0.09 0.13 0.1  0.16]
#
# #3.
# Graph Zoomed In:

# %% [markdown]
# # P2
#
# Using a simulation in which you keep track of the population (similar to what discussed in class), simulate the history of a population with a tri-allelic locus (e.g, `a1`,`a2` and `a3`).
#
# **Hint**: your initial population would be something like `['a1','a1','a1','a2','a3',...]` and then use the random sampling assumption to simulated the population dynamics

# %%
import numpy as np

['a1','a1','a1','a2','a3',...]

s = np.random.binomial(N, f, t)
history = []
N = 100.0
f = 0.1
t = 10

for _ in s:
    history.append(_)
        
thehistory = np.array(history)
print('The population history: ' + str(history))
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-1-c7463d364490> in <module>()
#       1 import numpy as np
#       2
# ----> 3 s = np.random.binomial(N, f, t)
#       4 history = []
#       5 N = 100.0
#
# NameError: name 'N' is not defined
